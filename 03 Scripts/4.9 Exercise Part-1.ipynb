# %% [markdown]
# # Task 4.9 Part-1

# %% [markdown]
# # 3. Import your analysis libraries, as well as your new customer data set as a dataframe.

# %%
# import data and libraries

import pandas as pd
import numpy as np
import os

# %%
# setting path
path = r'/Users/shikhakamboj/Documents/JAN-2025 Instacart Basket Analysis'

# %%
# importing data sets

df_customer = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'customers.csv'))

# %% [markdown]
# # 4. Wrangle the data so that it follows consistent logic; for example, rename columns with illogical names and drop columns that don’t add anything to your analysis.

# %%
# Checking the newly imported dataframe 

df_customer.head(10)
# Out:
#    user_id First Name    Surnam  Gender           STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female        Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female      New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male           Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female            Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female        Maryland   26    1/1/2017
# 5   133128    Cynthia     Noble  Female        Kentucky   43    1/1/2017
# 6   152052      Chris    Walton    Male         Montana   20    1/1/2017
# 7   168851     Joseph   Hickman    Male  South Carolina   30    1/1/2017
# 8    69965     Jeremy      Vang    Male           Texas   47    1/1/2017
# 9    82820      Shawn     Chung    Male        Virginia   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# ...

# %%
# Checking the dimensions of the dataframe
df_customer.shape
# Out:
# (206209, 10)

# %%
# checking the data types

df_customer.dtypes
# Out:
# user_id          int64
# First Name      object
# Surnam          object
# Gender          object
# STATE           object
# Age              int64
# date_joined     object
# n_dependants     int64
# fam_status      object
# income           int64
# dtype: object

# %%
df_customer.describe()
# Out:
#              user_id            Age   n_dependants         income
# count  206209.000000  206209.000000  206209.000000  206209.000000
# mean   103105.000000      49.501646       1.499823   94632.852548
# std     59527.555167      18.480962       1.118433   42473.786988
# min         1.000000      18.000000       0.000000   25903.000000
# 25%     51553.000000      33.000000       0.000000   59874.000000
# 50%    103105.000000      49.000000       1.000000   93547.000000
# 75%    154657.000000      66.000000       3.000000  124244.000000
# max    206209.000000      81.000000       3.000000  593901.000000

# %%
# Renaming columns

df_customer.rename(columns = {'First Name' : 'first_name'}, inplace = True)

# %%
df_customer.rename(columns = {'Surnam' : 'last_name'}, inplace = True)

# %%
df_customer.rename(columns = {'Gender' : 'gender'}, inplace = True)

# %%
df_customer.rename(columns = {'STATE' : 'state'}, inplace = True)

# %%
df_customer.rename(columns = {'Age' : 'age'}, inplace = True)

# %%
df_customer.rename(columns = {'n_dependants' : 'number_of_dependents'}, inplace = True)

# %%
df_customer.rename(columns = {'fam_status' : 'marital_status'}, inplace = True)

# %%
# checking columns
df_customer.columns
# Out:
# Index(['user_id', 'first_name', 'last_name', 'gender', 'state', 'age',
#        'date_joined', 'number_of_dependents', 'marital_status', 'income'],
#       dtype='object')

# %%
df_customer.head(10)
# Out:
#    user_id first_name last_name  gender           state  age date_joined  \
# 0    26711    Deborah  Esquivel  Female        Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female      New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male           Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female            Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female        Maryland   26    1/1/2017
# 5   133128    Cynthia     Noble  Female        Kentucky   43    1/1/2017
# 6   152052      Chris    Walton    Male         Montana   20    1/1/2017
# 7   168851     Joseph   Hickman    Male  South Carolina   30    1/1/2017
# 8    69965     Jeremy      Vang    Male           Texas   47    1/1/2017
# 9    82820      Shawn     Chung    Male        Virginia   26    1/1/2017
#
#    number_of_dependents marital_status  income
# 0                     3        married  165665
# 1                     0         single   59285
# ...

# %% [markdown]
# Columns have been renamed, and no columns need to be dropped at this time, as all are relevant and useful for analysis.

# %% [markdown]
# # 5. Complete the fundamental data quality and consistency checks you’ve learned throughout this Achievement

# %%
# Checking for mixed-type columns

for col in df_customer.columns.tolist():
  weird = (df_customer[[col]].map(type) != df_customer[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_customer[weird]) > 0:
    print (col)
# Out:
# first_name

# %% [markdown]
# Based on the above output, the "first name" column contains mixed data types, which need to be addressed.

# %%
df_customer['first_name'] = df_customer['first_name'].astype('str')

# %%
# Re-check the data-types in the data frame

df_customer.dtypes
# Out:
# user_id                  int64
# first_name              object
# last_name               object
# gender                  object
# state                   object
# age                      int64
# date_joined             object
# number_of_dependents     int64
# marital_status          object
# income                   int64
# dtype: object

# %%
# Checking for missing values

df_customer.isnull().sum()
# Out:
# user_id                 0
# first_name              0
# last_name               0
# gender                  0
# state                   0
# age                     0
# date_joined             0
# number_of_dependents    0
# marital_status          0
# income                  0
# dtype: int64

# %% [markdown]
# According to the above output, there are no missing values in the dataframe.

# %%
# Checking for duplicates

customer_dups = df_customer[df_customer.duplicated()]

# %%
customer_dups
# Out:
# Empty DataFrame
# Columns: [user_id, first_name, last_name, gender, state, age, date_joined, number_of_dependents, marital_status, income]
# Index: []

# %% [markdown]
# No duplicates found

# %%
df_customer.describe()
# Out:
#              user_id            age  number_of_dependents         income
# count  206209.000000  206209.000000         206209.000000  206209.000000
# mean   103105.000000      49.501646              1.499823   94632.852548
# std     59527.555167      18.480962              1.118433   42473.786988
# min         1.000000      18.000000              0.000000   25903.000000
# 25%     51553.000000      33.000000              0.000000   59874.000000
# 50%    103105.000000      49.000000              1.000000   93547.000000
# 75%    154657.000000      66.000000              3.000000  124244.000000
# max    206209.000000      81.000000              3.000000  593901.000000

# %% [markdown]
# Everything looks good; no issues detected in the data.

# %% [markdown]
# # 6. Combine your customer data with the rest of your prepared Instacart data.

# %%
# importing the instacart data

ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_updated_grouped_aggregated.pkl'))

# %%
# checking the newly imported data

ords_prods_merge.shape
# Out:
# (32404859, 24)

# %% [markdown]
# # Identifying shared column

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0         2   202279             3                   5                  9
# 1         2   202279             3                   5                  9
# 2         2   202279             3                   5                  9
# 3         2   202279             3                   5                  9
# 4         2   202279             3                   5                  9
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     8.0     33120.0                1.0        1.0
# 1                     8.0     28985.0                2.0        1.0
# 2                     8.0      9327.0                3.0        0.0
# 3                     8.0     45918.0                4.0        1.0
# 4                     8.0     30035.0                5.0        0.0
#
#             product_name  ...    price_range_loc     busiest day  \
# ...

# %%
df_customer.head()
# Out:
#    user_id first_name last_name  gender       state  age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    number_of_dependents marital_status  income
# 0                     3        married  165665
# 1                     0         single   59285
# 2                     2        married   99568
# 3                     0         single   42049
# 4                     1        married   40374

# %% [markdown]
# Both dataframes have a common column, user_id.

# %%
# Checking datatype of common column

ords_prods_merge.dtypes['user_id']
# Out:
# dtype('int64')

# %%
df_customer.dtypes['user_id']
# Out:
# dtype('int64')

# %% [markdown]
# Both key colummns have same datatype.

# %% [markdown]
# # Merging two dataframes

# %%
custs_ords_prods = ords_prods_merge.merge(df_customer, on = 'user_id', indicator = True)

# %%
custs_ords_prods.shape
# Out:
# (32404859, 34)

# %%
custs_ords_prods.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0         2   202279             3                   5                  9
# 1         2   202279             3                   5                  9
# 2         2   202279             3                   5                  9
# 3         2   202279             3                   5                  9
# 4         2   202279             3                   5                  9
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     8.0     33120.0                1.0        1.0
# 1                     8.0     28985.0                2.0        1.0
# 2                     8.0      9327.0                3.0        0.0
# 3                     8.0     45918.0                4.0        1.0
# 4                     8.0     30035.0                5.0        0.0
#
#             product_name  ...  first_name  last_name  gender  state age  \
# ...

# %% [markdown]
# # 8. Export this new dataframe as a pickle file so you can continue to use it in the second part of this task.

# %%
custs_ords_prods.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_customers_merged.pkl'))
